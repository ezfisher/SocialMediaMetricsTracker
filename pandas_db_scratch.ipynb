# %%
import numpy as np
import os
import pandas as pd

# %%
df_cols = ['RowId', 'DatePosted', 'MetricsTakenDate', 'MetricsTakenTime', 'NumMetricsMeasurements', 'DayOfWeekPosted', 'PostId', 'Title', 'FilePath', 'DailyWeekly', 'Likes', 'Views', 'NumComments']
row1 = {
    'RowId':1,
    'DatePosted':'2024-07-05',
    'MetricsTakenDate':'2024-07-05',
    'MetricsTakenTime':'14:44',
    'NumMetricsMeasurements':1,
    'DayOfWeekPosted':'Friday',
    'PostId':1,
    'Title':'post_1_title',
    'FilePath':'/path/to/post_1',
    'DailyWeekly':'Daily',
    'Likes':0,
    'Views':0,
    'NumComments':0
}

df = pd.DataFrame([row1], columns=df_cols)

# %%
row2 = {
    'RowId':2,
    'DatePosted':'2024-07-05',
    'MetricsTakenDate':'2024-07-05',
    'MetricsTakenTime':'14:44',
    'NumMetricsMeasurements':1,
    'DayOfWeekPosted':'Friday',
    'PostId':2,
    'Title':'post_2_title',
    'FilePath':'/path/to/post_2',
    'DailyWeekly':'Daily',
    'Likes':0,
    'Views':0,
    'NumComments':0
}

df = pd.concat((df, pd.DataFrame([row2], columns=df_cols)), axis=0)

# %%
row3 = {
    'RowId':3,
    'DatePosted':'2024-07-05',
    'MetricsTakenDate':'2024-07-05',
    'MetricsTakenTime':'20:44',
    'NumMetricsMeasurements':2,
    'DayOfWeekPosted':'Friday',
    'PostId':1,
    'Title':'post_1_title',
    'FilePath':'/path/to/post_1',
    'DailyWeekly':'Daily',
    'Likes':1,
    'Views':4,
    'NumComments':1
}

df = pd.concat((df, pd.DataFrame([row3], columns=df_cols)), axis=0)
df
# Out:
#    RowId  DatePosted MetricsTakenDate MetricsTakenTime  \
# 0      1  2024-07-05       2024-07-05            14:44
# 0      2  2024-07-05       2024-07-05            14:44
# 0      3  2024-07-05       2024-07-05            20:44
#
#    NumMetricsMeasurements DayOfWeekPosted  PostId         Title  \
# 0                       1          Friday       1  post_1_title
# 0                       1          Friday       2  post_2_title
# 0                       2          Friday       1  post_1_title
#
#           FilePath DailyWeekly  Likes  Views  NumComments
# 0  /path/to/post_1       Daily      0      0            0
# 0  /path/to/post_2       Daily      0      0            0
# 0  /path/to/post_1       Daily      1      4            1

# %%
post1_df = df[df['PostId'] == 1]
post1_df
# Out:
#    RowId  DatePosted MetricsTakenDate MetricsTakenTime  \
# 0      1  2024-07-05       2024-07-05            14:44
# 0      3  2024-07-05       2024-07-05            20:44
#
#    NumMetricsMeasurements DayOfWeekPosted  PostId         Title  \
# 0                       1          Friday       1  post_1_title
# 0                       2          Friday       1  post_1_title
#
#           FilePath DailyWeekly  Likes  Views  NumComments
# 0  /path/to/post_1       Daily      0      0            0
# 0  /path/to/post_1       Daily      1      4            1
